# %% [markdown]
# <a href="https://colab.research.google.com/github/MaferLedmar/Actividad5_RegresionLinealSimple/blob/main/Actividad_5_Girona.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3c722ae3-2bd5-4e83-b1b2-bc7233f2f336" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c722ae3-2bd5-4e83-b1b2-bc7233f2f336">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('Girona_España.csv', encoding='latin')
data
# Out:
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 1      1.205757e+06             https://www.airbnb.com/rooms/1205757
# 2      1.212820e+06             https://www.airbnb.com/rooms/1212820
# 3      7.516380e+05              https://www.airbnb.com/rooms/751638
# 4      4.134200e+04               https://www.airbnb.com/rooms/41342
# ...             ...                                              ...
# 19650  8.583870e+17  https://www.airbnb.com/rooms/858386613168601750
# 19651  8.583960e+17  https://www.airbnb.com/rooms/858396134121337855
# 19652  8.584110e+17  https://www.airbnb.com/rooms/858410917126332945
# 19653  8.584180e+17  https://www.airbnb.com/rooms/858418062773719271
# 19654  8.584240e+17  https://www.airbnb.com/rooms/858424461046143986
#
#           scrape_id last_scraped           source  \
# 0      2.023030e+13   31/03/2023      city scrape
# ...

# %% [markdown]
# #Limpieza y extracción de datos

# %%
#Mantenermos columnas a utilizar
df=data.iloc[:,[16,17,40,54,56,63,65,66,74]]
df1 = data.iloc[:,[33]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19655 entries, 0 to 19654
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_response_rate           17567 non-null  object
#  1   host_acceptance_rate         18502 non-null  object
#  2   price                        19655 non-null  object
#  3   availability_365             19655 non-null  int64
#  4   number_of_reviews            19655 non-null  int64
#  5   review_scores_cleanliness    14372 non-null  float64
#  6   review_scores_communication  14370 non-null  float64
#  7   review_scores_location       14371 non-null  float64
#  8   reviews_per_month            14428 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 1.3+ MB

# %%
df['host_response_rate'] = df['host_response_rate'].str.replace('%', '')
df['host_acceptance_rate'] = df['host_acceptance_rate'].str.replace('%', '')
df['price'] = df['price'].str.replace('$', '')
df
# Out:
# <ipython-input-12-dbcc6ec4eae6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_response_rate'] = df['host_response_rate'].str.replace('%', '')
# <ipython-input-12-dbcc6ec4eae6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_acceptance_rate'] = df['host_acceptance_rate'].str.replace('%', '')
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19655 entries, 0 to 19654
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_response_rate           17567 non-null  object
#  1   host_acceptance_rate         18502 non-null  object
#  2   price                        19655 non-null  object
#  3   availability_365             19655 non-null  int64
#  4   number_of_reviews            19655 non-null  int64
#  5   review_scores_cleanliness    14372 non-null  float64
#  6   review_scores_communication  14370 non-null  float64
#  7   review_scores_location       14371 non-null  float64
#  8   reviews_per_month            14428 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 1.3+ MB

# %%
df['host_response_rate'] = df['host_response_rate'].astype(float)
df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(float)
df['price'] = df['price'].str.replace(',', '')
df['price'] = df['price'].astype(float)
# Out:
# <ipython-input-14-f741e468b55e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_response_rate'] = df['host_response_rate'].astype(float)
# <ipython-input-14-f741e468b55e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(float)
# <ipython-input-14-f741e468b55e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19655 entries, 0 to 19654
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_response_rate           17567 non-null  float64
#  1   host_acceptance_rate         18502 non-null  float64
#  2   price                        19655 non-null  float64
#  3   availability_365             19655 non-null  int64
#  4   number_of_reviews            19655 non-null  int64
#  5   review_scores_cleanliness    14372 non-null  float64
#  6   review_scores_communication  14370 non-null  float64
#  7   review_scores_location       14371 non-null  float64
#  8   reviews_per_month            14428 non-null  float64
# dtypes: float64(7), int64(2)
# memory usage: 1.3 MB

# %%
#Reemplazamos valores atípicos (nulos) del data frame con "mean"
df_clean=df.copy()
df_clean=df_clean.fillna(round(df.mean(), 1))
df_clean
# Out:
#        host_response_rate  host_acceptance_rate  price  availability_365  \
# 0                   100.0                  90.0   42.0               293
# 1                   100.0                  42.0   47.0               282
# 2                   100.0                  80.0   74.0               315
# 3                   100.0                  91.0   45.0               248
# 4                    94.4                   0.0  120.0                 0
# ...                   ...                   ...    ...               ...
# 19650                93.0                 100.0  209.0               107
# 19651               100.0                 100.0   52.0               186
# 19652                43.0                  50.0   66.0               269
# 19653                93.0                  99.0  108.0               273
# 19654                43.0                  50.0   73.0                92
#
#        number_of_reviews  review_scores_cleanliness  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df_clean.isnull().sum()
valores_nulos
# Out:
# host_response_rate             0
# host_acceptance_rate           0
# price                          0
# availability_365               0
# number_of_reviews              0
# review_scores_cleanliness      0
# review_scores_communication    0
# review_scores_location         0
# reviews_per_month              0
# dtype: int64

# %%
#Metodo applicando cuartiles. Encuentro cuartiles 0.25 y 0.75

y=df_clean

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q2
iqr= percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print('Limite superior permitido', Limite_Superior_iqr)
print('Limite inferior permitido', Limite_Inferior_iqr)
# Out:
# Limite superior permitido host_response_rate             108.400
# host_acceptance_rate           115.750
# price                          387.500
# availability_365               580.500
# number_of_reviews               35.000
# review_scores_cleanliness        5.475
# review_scores_communication      5.450
# review_scores_location           5.375
# reviews_per_month                1.025
# dtype: float64
# Limite inferior permitido host_response_rate              86.000
# host_acceptance_rate            73.750
# price                          -88.500
# availability_365              -191.500
# number_of_reviews              -21.000
# review_scores_cleanliness        3.915
# review_scores_communication      4.250
# review_scores_location           4.295
# reviews_per_month               -0.375
# dtype: float64

# %%
#Obtenemos datos limpios del DataFrame
df_clean_iqr = df_clean[(y<=Limite_Superior_iqr) & (y>=Limite_Inferior_iqr)]
df_clean_iqr
# Out:
#        host_response_rate  host_acceptance_rate  price  availability_365  \
# 0                   100.0                  90.0   42.0               293
# 1                   100.0                   NaN   47.0               282
# 2                   100.0                  80.0   74.0               315
# 3                   100.0                  91.0   45.0               248
# 4                    94.4                   NaN  120.0                 0
# ...                   ...                   ...    ...               ...
# 19650                93.0                 100.0  209.0               107
# 19651               100.0                 100.0   52.0               186
# 19652                 NaN                   NaN   66.0               269
# 19653                93.0                  99.0  108.0               273
# 19654                 NaN                   NaN   73.0                92
#
#        number_of_reviews  review_scores_cleanliness  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df_clean_iqr.isnull().sum()
valores_nulos
# Out:
# host_response_rate             1659
# host_acceptance_rate           2424
# price                          1944
# availability_365                  0
# number_of_reviews              2247
# review_scores_cleanliness      1359
# review_scores_communication    1590
# review_scores_location         1502
# reviews_per_month              1887
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del data frame con "mean"
df_clean=df_clean_iqr.copy()
df_clean=df_clean_iqr.fillna(round(df_clean_iqr.mean(), 1))
df_clean
# Out:
#        host_response_rate  host_acceptance_rate  price  availability_365  \
# 0                   100.0                  90.0   42.0               293
# 1                   100.0                  95.9   47.0               282
# 2                   100.0                  80.0   74.0               315
# 3                   100.0                  91.0   45.0               248
# 4                    94.4                  95.9  120.0                 0
# ...                   ...                   ...    ...               ...
# 19650                93.0                 100.0  209.0               107
# 19651               100.0                 100.0   52.0               186
# 19652                97.8                  95.9   66.0               269
# 19653                93.0                  99.0  108.0               273
# 19654                97.8                  95.9   73.0                92
#
#        number_of_reviews  review_scores_cleanliness  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df_clean.isnull().sum()
valores_nulos
# Out:
# host_response_rate             0
# host_acceptance_rate           0
# price                          0
# availability_365               0
# number_of_reviews              0
# review_scores_cleanliness      0
# review_scores_communication    0
# review_scores_location         0
# reviews_per_month              0
# dtype: int64

# %%
#Corroboramos valores nulos
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# room_type    0
# dtype: int64

# %%
df_clean_complete = pd.concat([df_clean, df1], axis=1)
df_clean_complete
# Out:
#        host_response_rate  host_acceptance_rate  price  availability_365  \
# 0                   100.0                  90.0   42.0               293
# 1                   100.0                  95.9   47.0               282
# 2                   100.0                  80.0   74.0               315
# 3                   100.0                  91.0   45.0               248
# 4                    94.4                  95.9  120.0                 0
# ...                   ...                   ...    ...               ...
# 19650                93.0                 100.0  209.0               107
# 19651               100.0                 100.0   52.0               186
# 19652                97.8                  95.9   66.0               269
# 19653                93.0                  99.0  108.0               273
# 19654                97.8                  95.9   73.0                92
#
#        number_of_reviews  review_scores_cleanliness  \
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df_clean_complete.isnull().sum()
valores_nulos
# Out:
# host_response_rate             0
# host_acceptance_rate           0
# price                          0
# availability_365               0
# number_of_reviews              0
# review_scores_cleanliness      0
# review_scores_communication    0
# review_scores_location         0
# reviews_per_month              0
# room_type                      0
# dtype: int64

# %%
from google.colab import files
df_clean_complete.to_csv('Girona_Clean.csv')
files.download('Girona_Clean.csv')
